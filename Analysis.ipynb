# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
#read the csv
df = pd.read_csv("Billionaire.csv")
df
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry
# ...

# %%
df.head(100)
# Out:
#                            Name NetWorth        Country  \
# 0                    Jeff Bezos   $177 B  United States
# 1                     Elon Musk   $151 B  United States
# 2      Bernard Arnault & family   $150 B         France
# 3                    Bill Gates   $124 B  United States
# 4               Mark Zuckerberg    $97 B  United States
# ..                          ...      ...            ...
# 95                 Eric Schmidt  $18.9 B  United States
# 96                 Sun Piaoyang  $18.9 B          China
# 97  Theo Albrecht, Jr. & family  $18.8 B        Germany
# 98              Alisher Usmanov  $18.4 B         Russia
# 99                  Robert Pera  $18.3 B  United States
#
#                          Source  Rank   Age          Industry
# 0                        Amazon     1  57.0        Technology
# 1                 Tesla, SpaceX     2  49.0        Automotive
# 2                          LVMH     3  72.0  Fashion & Retail
# ...

# %%
#checking the value if there is null
df.isnull()
# Out:
#        Name  NetWorth  Country  Source   Rank    Age  Industry
# 0     False     False    False   False  False  False     False
# 1     False     False    False   False  False  False     False
# 2     False     False    False   False  False  False     False
# 3     False     False    False   False  False  False     False
# 4     False     False    False   False  False  False     False
# ...     ...       ...      ...     ...    ...    ...       ...
# 2750  False     False    False   False  False  False     False
# 2751  False     False    False   False  False  False     False
# 2752  False     False    False   False  False  False     False
# 2753  False     False    False   False  False  False     False
# 2754  False     False    False   False  False  False     False
#
# [2755 rows x 7 columns]

# %%
#information of thw csv file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      2755 non-null   object
#  1   NetWorth  2755 non-null   object
#  2   Country   2755 non-null   object
#  3   Source    2755 non-null   object
#  4   Rank      2755 non-null   int64
#  5   Age       2676 non-null   float64
#  6   Industry  2755 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 150.8+ KB

# %%
#checking dataset at different percentile
df.describe()
# Out:
#               Rank          Age
# count  2755.000000  2676.000000
# mean   1345.663521    63.113602
# std     772.669811    13.445153
# min       1.000000    18.000000
# 25%     680.000000    54.000000
# 50%    1362.000000    63.000000
# 75%    2035.000000    73.000000
# max    2674.000000    99.000000

# %%
df["Country"].value_counts().head(10)
#usa have highest number of the billionaire
# Out:
# United States     724
# China             626
# India             140
# Germany           136
# Russia            118
# Hong Kong          71
# Brazil             65
# Canada             64
# United Kingdom     56
# Italy              51
# Name: Country, dtype: int64

# %%
df["Industry"].value_counts()
#industry in finance and investment has highest number of the billionaire
# Out:
# Finance & Investments         371
# Technology                    365
# Manufacturing                 331
# Fashion & Retail              273
# Healthcare                    221
# Food & Beverage               219
# Real Estate                   215
# Diversified                   188
# Energy                        100
# Media & Entertainment          95
# Service                        75
# Metals & Mining                74
# Automotive                     68
# Construction & Engineering     44
# Logistics                      35
# Telecom                        32
# Gambling & Casinos             25
# Sports                         24
# Name: Industry, dtype: int64

# %%
#remove each string from 
df['NetWorth_Billion_Dollars'] = df['NetWorth'].replace({'\$': '', 'B': ''}, regex=True).astype(float)

# %%
df
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry  NetWorth_Billion_Dollars
# ...

# %%
df1 = df.drop(columns="NetWorth")

# %%
df1.describe()
# Out:
#               Rank          Age  NetWorth_Billion_Dollars
# count  2755.000000  2676.000000               2755.000000
# mean   1345.663521    63.113602                  4.749220
# std     772.669811    13.445153                  9.615358
# min       1.000000    18.000000                  1.000000
# 25%     680.000000    54.000000                  1.500000
# 50%    1362.000000    63.000000                  2.300000
# 75%    2035.000000    73.000000                  4.200000
# max    2674.000000    99.000000                177.000000

# %%
df1.Rank.value_counts()
# means they share same rank
# Out:
# 2524    150
# 2378    146
# 2141    122
# 2263    115
# 2035    106
#        ...
# 77        1
# 73        1
# 69        1
# 65        1
# 2         1
# Name: Rank, Length: 245, dtype: int64

# %%
####We can have a an absolute unique rank for each person
df1['Abs_rank']=df.index+1
df1
# Out:
#                           Name        Country         Source  Rank   Age  \
# 0                   Jeff Bezos  United States         Amazon     1  57.0
# 1                    Elon Musk  United States  Tesla, SpaceX     2  49.0
# 2     Bernard Arnault & family         France           LVMH     3  72.0
# 3                   Bill Gates  United States      Microsoft     4  65.0
# 4              Mark Zuckerberg  United States       Facebook     5  36.0
# ...                        ...            ...            ...   ...   ...
# 2750         Daniel Yong Zhang          China     e-commerce  2674  49.0
# 2751             Zhang Yuqiang          China     Fiberglass  2674  65.0
# 2752             Zhao Meiguang          China    gold mining  2674  58.0
# 2753            Zhong Naixiong          China   conglomerate  2674  58.0
# 2754           Zhou Wei family          China       Software  2674  54.0
#
#               Industry  NetWorth_Billion_Dollars  Abs_rank
# ...

# %%
len(df1)
# there are 2755 billionaire in the world(feb -2021)
# Out:
# 2755

# %%
##How does age correlate to how rich you are given that you are a billionaire? What is the distribution of billionaire's ages?

df1["Age"].hist(bins=30)
plt.title("Billionaire Age Histogram")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
## Average and Median of billionaires
meanAge = df1["Age"].mean()
medianAge = df1["Age"].median()

print("The average billionaire age is {} and the median age is {}.".format(meanAge, medianAge))
# Out:
# The average billionaire age is 63.1136023916293 and the median age is 63.0.

# %%
#### plottting networth vs rank.. we have plotted matplotlib for it above 
#only taking top 200 bilionaire
#Exploring Net Worth Vs Ranks(top 200)

plt.figure(figsize=(14,7))
plt.plot(df1.Rank[:200],df1.NetWorth_Billion_Dollars[:200],c='pink',lw=4)
plt.xlabel('Ranks')
plt.ylabel('Net Worth(Billion-$)')
plt.title('Wealth Distrbution')

sns.set_style('whitegrid')

# %% [markdown]
# ### this shows as we move up the rank there is large change  in net worth

# %%
#Frequency of Top 200 Billionaires Across Range of NetWorth
plt.hist(df1.NetWorth_Billion_Dollars[df1.Rank<=200],bins=10)
plt.xlabel('Range')
plt.ylabel('Frequency')


plt.title('Frequency of Top 200 Billionaires Acc. to Net Worth');

# %% [markdown]
# ### as expected the count of billionaire are veryy low at lower range of Net Worth

# %%
plt.figure(figsize = (18,12))
plt.bar(x =df1['Country'], height = df1['NetWorth_Billion_Dollars'],color = 'midnightblue' )
plt.xticks(rotation = 90,fontsize = 15)
plt.yticks(fontsize = 15)
plt.title('Countries with the Richest Billionaires in the World',fontsize = 16)

plt.savefig('Countries with the Richest Billionaires in the World.png')

plt.show()

# %%
### top 5 domains with the most number of billionaires:

a = df1["Source"].value_counts().head()
index = a.index
sources = a.values
custom_colors = ["blue", "yellow", 'grey', "green", "red"]
plt.figure(figsize=(8, 8))
plt.pie(sources, labels=index, colors=custom_colors)
central_circle = plt.Circle((0,0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=20)
plt.title("Top 5 Domains to Become a Billionaire", fontsize=20)
plt.show()

# %% [markdown]
# ### In this we found that  pharmaceuticals and real state domains have most number of billionares...

# %%
###top 5 industries with the most number of billionaires:


a = df1["Industry"].value_counts().head()
index = a.index
industries = a.values
custom_colors = ["blue", "yellow", 'grey', "green", "red"]
plt.figure(figsize=(8,8))
plt.pie(industries, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=20)
plt.title("Top 5 Industries with Most Number of Billionaires", fontsize=20)
plt.show()

# %% [markdown]
# ### In this we found that TECHNOLOGY , FINANCE & INVESTEMENTS and MANUFACTURING have most number of billionares...

# %%
### top 5 countries with the most number of billionaires:

a = df1["Country"].value_counts().head()
index = a.index
Countries = a.values
custom_colors = ["blue", "yellow", 'grey', "green", "red"]
plt.figure(figsize=(8,8))
plt.pie(Countries, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=20)
plt.title("Top 5 Countries with Most Number of Billionaires", fontsize=20)
plt.show()

# %% [markdown]
# ### At the end of the analysis of global billionaires, I found that China and the United States are the countries with the most billionaires which concludes that the business environment and the success rate of a startup is much better in the US and China than in the rest of the world.

# %% [markdown]
# ### Conclusion
# ### 1.there are total '2755' Billionaires in The World(FEB-2021).
# ### 2.We see that there is large change in net worth as we move up the ranks .
# ### 3. U.S tops in Billionaires Count and net Billionaires wealth
# ### 4.We can conclude that Real State major source of Our Billionaires.China have most Billionairesl in Working in RealeState.
# ### 5.The average billionaire age is 63.1136023916293 and the median age is 63.0.
